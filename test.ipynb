# %%
import pandas as pd

# %%
df = pd.read_csv('cleaned_dataset.csv')
df
# Out:
#        serial_number  project_id  project_code legacy_ocms_code pmgid  \
# 0                  1       40000         40000                -     -
# 1                 11       40000         40000                -     -
# 2                 21       40000         40000                -     -
# 3                 12       40001         40001                -     -
# 4                 12       40001         40001                -     -
# ...              ...         ...           ...              ...   ...
# 18358           1732      914467        914467                -     -
# 18359           1733      938832        938832                -     -
# 18360            504      944288        944288                -     -
# 18361           1734      946208        946208                -     -
# 18362           1735      976009        976009                -     -
#
#                                             project_name  \
# 0      CO CIVIL AVIATION REASEARCH ORG. (PH-II) AT BE...
# ...

# %%
filtered_df = df[df['project_name'] == 'BharatNet']
filtered_df.head()
# Out:
#    serial_number  project_id  project_code legacy_ocms_code pmgid  \
# 0              1       40000         40000                -     -
# 1             11       40000         40000                -     -
# 2             21       40000         40000                -     -
# 3             12       40001         40001                -     -
# 4             12       40001         40001                -     -
#
#   project_name agency           state date_of_approval  start_date  ...  \
# 0    BharatNet    AAI  ANDHRA PRADESH       2022-06-01  2022-07-01  ...
# 1    BharatNet    AAI             NaN       2022-06-01  2022-07-01  ...
# 2    BharatNet    AAI             NaN       2022-06-01  2022-07-01  ...
# 3    BharatNet    AAI             NaN       2025-08-01  2024-07-01  ...
# 4    BharatNet    AAI             NaN       2025-08-01  2024-07-01  ...
#
#   risk_score risk_class target_cost  target_delay  target_future_cost  \
# ...
